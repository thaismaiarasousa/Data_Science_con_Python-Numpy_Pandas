# %%
#Crear el df a partir de un fichero determinado, relacionado al trafico peatonal.

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\5.8\PEATONES_2020_mod.csv', delimiter=";",encoding="ISO-8859-1")

# %%
df.shape
# Out:
# (288755, 12)

# %%
df.head(10)
# Out:
#         FECHA     HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# 0  01/01/2020  0:00:00  PERM_PEA02_PM01     497.0              1.0   Centro
# 1  01/01/2020  0:15:00  PERM_PEA02_PM01     244.0              1.0   Centro
# 2  01/01/2020  0:30:00  PERM_PEA02_PM01     179.0              1.0   Centro
# 3  01/01/2020  0:45:00  PERM_PEA02_PM01     174.0              1.0   Centro
# 4  01/01/2020  1:00:00  PERM_PEA02_PM01     131.0              1.0   Centro
# 5  01/01/2020  1:15:00  PERM_PEA02_PM01      95.0              1.0   Centro
# 6  01/01/2020  1:30:00  PERM_PEA02_PM01       NaN              1.0   Centro
# 7  01/01/2020  1:45:00  PERM_PEA02_PM01     175.0              1.0   Centro
# 8  01/01/2020  2:00:00  PERM_PEA02_PM01     149.0              1.0   Centro
# 9  01/01/2020  2:15:00  PERM_PEA02_PM01     126.0              1.0   Centro
#
#         NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL         OBSERVACIONES_DIRECCION  \
# ...

# %%
#Crear un segundo df con el filtrado de datos necesario si queremos enfocar nuestros analisis en que ocurrio los dias comprendios en el rango [01-01/2020 // 01-05-2020]

# %%
#Realizar el filtrado para el distrito "Centro" utilizando str.constains

# %%
df2=df[(df["FECHA"]>="01/01/2020") & (df["FECHA"]<="01/05/2020") & (df["DISTRITO"].str.contains("Centro"))]

# %%
df2
# Out:
#              FECHA      HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO  \
# 0       01/01/2020   0:00:00  PERM_PEA02_PM01     497.0              1.0
# 1       01/01/2020   0:15:00  PERM_PEA02_PM01     244.0              1.0
# 2       01/01/2020   0:30:00  PERM_PEA02_PM01     179.0              1.0
# 3       01/01/2020   0:45:00  PERM_PEA02_PM01     174.0              1.0
# 4       01/01/2020   1:00:00  PERM_PEA02_PM01     131.0              1.0
# ...            ...       ...              ...       ...              ...
# 283028  01/05/2020  22:45:00  PERM_PEA19_PM01     568.0              1.0
# 283029  01/05/2020  23:00:00  PERM_PEA19_PM01     588.0              1.0
# 283030  01/05/2020  23:15:00  PERM_PEA19_PM01     504.0              1.0
# 283031  01/05/2020  23:30:00  PERM_PEA19_PM01     554.0              1.0
# 283032  01/05/2020  23:45:00  PERM_PEA19_PM01     492.0              1.0
#
#        DISTRITO       NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL  \
# ...

# %%
#Verificar si hay valores erroneos en la columna "PEATONES" en estas condiciones, en caso afirmativo crear el dataframe df_interp con la interpolacion lineal del segundo df.

# %%
df2.count()
# Out:
# FECHA                      5178
# HORA                       5178
# IDENTIFICADOR              5178
# PEATONES                   5176
# NÚMERO_DISTRITO            5178
# DISTRITO                   5178
# NOMBRE_VIAL                5178
# NÚMERO                     5178
# CÓDIGO_POSTAL              5178
# OBSERVACIONES_DIRECCION    5178
# LATITUD                    5178
# LONGITUD                   5178
# dtype: int64

# %%
#Si hay 2 registros NaN en PEATONES.

# %%
df2.head(10)
# Out:
#         FECHA     HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# 0  01/01/2020  0:00:00  PERM_PEA02_PM01     497.0              1.0   Centro
# 1  01/01/2020  0:15:00  PERM_PEA02_PM01     244.0              1.0   Centro
# 2  01/01/2020  0:30:00  PERM_PEA02_PM01     179.0              1.0   Centro
# 3  01/01/2020  0:45:00  PERM_PEA02_PM01     174.0              1.0   Centro
# 4  01/01/2020  1:00:00  PERM_PEA02_PM01     131.0              1.0   Centro
# 5  01/01/2020  1:15:00  PERM_PEA02_PM01      95.0              1.0   Centro
# 6  01/01/2020  1:30:00  PERM_PEA02_PM01       NaN              1.0   Centro
# 7  01/01/2020  1:45:00  PERM_PEA02_PM01     175.0              1.0   Centro
# 8  01/01/2020  2:00:00  PERM_PEA02_PM01     149.0              1.0   Centro
# 9  01/01/2020  2:15:00  PERM_PEA02_PM01     126.0              1.0   Centro
#
#         NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL         OBSERVACIONES_DIRECCION  \
# ...

# %%
df_interp=df2.interpolate(method='linear', limit_direction='forward') #Crio un nuevo df para interpolar los datos NaN de df2_PEATONES

# %%
df_interp.count() #Verifico la cuenta
# Out:
# FECHA                      5178
# HORA                       5178
# IDENTIFICADOR              5178
# PEATONES                   5178
# NÚMERO_DISTRITO            5178
# DISTRITO                   5178
# NOMBRE_VIAL                5178
# NÚMERO                     5178
# CÓDIGO_POSTAL              5178
# OBSERVACIONES_DIRECCION    5178
# LATITUD                    5178
# LONGITUD                   5178
# dtype: int64

# %%
df_interp.head(10) #Verifico el df con datos interpolados.
# Out:
#         FECHA     HORA    IDENTIFICADOR  PEATONES  NÚMERO_DISTRITO DISTRITO  \
# 0  01/01/2020  0:00:00  PERM_PEA02_PM01     497.0              1.0   Centro
# 1  01/01/2020  0:15:00  PERM_PEA02_PM01     244.0              1.0   Centro
# 2  01/01/2020  0:30:00  PERM_PEA02_PM01     179.0              1.0   Centro
# 3  01/01/2020  0:45:00  PERM_PEA02_PM01     174.0              1.0   Centro
# 4  01/01/2020  1:00:00  PERM_PEA02_PM01     131.0              1.0   Centro
# 5  01/01/2020  1:15:00  PERM_PEA02_PM01      95.0              1.0   Centro
# 6  01/01/2020  1:30:00  PERM_PEA02_PM01     135.0              1.0   Centro
# 7  01/01/2020  1:45:00  PERM_PEA02_PM01     175.0              1.0   Centro
# 8  01/01/2020  2:00:00  PERM_PEA02_PM01     149.0              1.0   Centro
# 9  01/01/2020  2:15:00  PERM_PEA02_PM01     126.0              1.0   Centro
#
#         NOMBRE_VIAL  NÚMERO  CÓDIGO_POSTAL         OBSERVACIONES_DIRECCION  \
# ...
