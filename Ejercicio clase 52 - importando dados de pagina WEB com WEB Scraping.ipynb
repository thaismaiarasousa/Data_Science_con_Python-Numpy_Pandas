# %%
import pandas as pd
import requests

# %%
url="https://en.wikipedia.org/wiki/List_of_countries_by_average_wage"

# %%
r=requests.get(url)

# %%
html_doc=r.text

# %%
html_doc
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of countries by average wage - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"1ed04985-30b3-44a6-a0f6-321a2294cc35","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_average_wage","wgTitle":"List of countries by average wage","wgCurRevisionId":1102236631,"wgRevisionId":1102236631,"wgArticleId":24486462,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Lis
# ...

# %%
df_lista=pd.read_html(r.text) #Parsea todas as tabelas da url y as inserta em uma lista, cada elemento eh um df.

# %%
df=df_lista[0]

# %%
df
# Out:
#              Country   2000   2005   2010   2011   2012   2013   2014   2015  \
# 0    United States *  55366  58092  61048  61132  61634  61347  62263  63845
# 1          Iceland *  53810  61187  51234  53452  53137  53966  54736  58377
# 2       Luxembourg *  57100  59505  63917  62955  62451  63058  65379  66247
# 3      Switzerland *  56529  61063  63277  63533  64582  65431  65548  65910
# 4      Netherlands *  52371  54565  57959  57601  57835  58035  57729  58403
# 5          Denmark *  46360  50879  54928  54644  54570  54925  55976  56960
# 6           Norway *  38647  44438  50586  42347  53777  54853  55121  55404
# 7           Canada *  44108  45824  50024  50512  51289  51924  52557  52968
# 8        Australia *  45201  48615  51957  53601  53919  53672  54085  53636
# 9          Belgium *  51922  52969  53969  54520  54951  55503  55809  55427
# 10         Germany *  45584  46553  47054  48026  48683  49159  50001  51172
# ...

# %%
# importar dados da url mencionada, de tal maneira que obtenhamos a tabela de ingressos medios mensais por pais.

# %%
url_ej="https://en.wikipedia.org/wiki/List_of_countries_by_average_wage"

# %%
r=requests.get(url_ej)

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of countries by average wage - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"1ed04985-30b3-44a6-a0f6-321a2294cc35","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_average_wage","wgTitle":"List of countries by average wage","wgCurRevisionId":1102236631,"wgRevisionId":1102236631,"wgArticleId":24486462,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Lis
# ...

# %%
df_lista_ej=pd.read_html(r.text)

# %%
df1=df_lista_ej[15]
df1
# Out:
#              Country   2000   2005   2010   2011   2012   2013   2014   2015  \
# 0    United States *  55366  58092  61048  61132  61634  61347  62263  63845
# 1          Iceland *  53810  61187  51234  53452  53137  53966  54736  58377
# 2       Luxembourg *  57100  59505  63917  62955  62451  63058  65379  66247
# 3      Switzerland *  56529  61063  63277  63533  64582  65431  65548  65910
# 4      Netherlands *  52371  54565  57959  57601  57835  58035  57729  58403
# 5          Denmark *  46360  50879  54928  54644  54570  54925  55976  56960
# 6           Norway *  38647  44438  50586  42347  53777  54853  55121  55404
# 7           Canada *  44108  45824  50024  50512  51289  51924  52557  52968
# 8        Australia *  45201  48615  51957  53601  53919  53672  54085  53636
# 9          Belgium *  51922  52969  53969  54520  54951  55503  55809  55427
# 10         Germany *  45584  46553  47054  48026  48683  49159  50001  51172
# ...
