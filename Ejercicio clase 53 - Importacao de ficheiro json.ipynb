# %% [markdown]
# # Importacao de ficheiro json

# %%
import json

# %%
import pandas as pd

# %%
with open(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\6.6\divisions.json','r') as json_file:
    json_data=json.load(json_file)

# %%
type(json_data)
# Out:
# dict

# %%
json_data
# Out:
# {'head': {'counts': {'divisionCount': 13915, 'resultCount': 13915},
#   'dateRange': {'start': '1900-01-01T00:00:00.000Z',
#    'end': '2099-01-01T00:00:00.000Z'},
#   'lang': 'mul'},
#  'results': [{'contextDate': '2020-05-27',
#    'division': {'outcome': 'Carried',
#     'debate': {'uri': 'https://data.oireachtas.ie/akn/ie/debateRecord/dail/2020-05-27/debate/main',
#      'debateSection': 'dbsect_2',
#      'formats': {'pdf': None,
#       'xml': {'uri': 'https://data.oireachtas.ie/akn/ie/debateRecord/dail/2020-05-27/debate/mul@/main.xml'}},
#      'showAs': 'An tOrd GnÃ³ - Order of Business'},
#     'tellers': 'Tellers: TÃ¡, Deputies Frankie Feighan and Peter Burke; NÃ\xadl, Deputies Danny Healy-Rae and Mattie McGrath.',
#     'voteId': 'vote_12',
#     'datetime': '2020-05-27T12:00:00+01:00',
#     'subject': {'uri': None,
#      'showAs': 'Question put: "That the proposal for dealing with Thursday\'s business be agreed to."'},
#     'house': {'houseCode': 'dail',
# ...

# %%
#Cargando esta informacion en el df:

# %%
from pandas.io.json import json_normalize
import json

with open(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\6.6\divisions.json','r') as json_file:
    d=json_data=json.load(json_file)

df = json_normalize(d,'results')
df.head()
# Out:
# C:\Users\thais\AppData\Local\Temp\ipykernel_12924\1445308763.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df = json_normalize(d,'results')
#   contextDate division.outcome  \
# 0  2020-05-27          Carried
# 1  2020-05-13             Lost
# 2  2020-05-12             Lost
# 3  2020-03-26             Lost
# 4  2020-03-26          Carried
#
#                                  division.debate.uri  \
# 0  https://data.oireachtas.ie/akn/ie/debateRecord...
# 1  https://data.oireachtas.ie/akn/ie/debateRecord...
# 2  https://data.oireachtas.ie/akn/ie/debateRecord...
# 3  https://data.oireachtas.ie/akn/ie/debateRecord...
# 4  https://data.oireachtas.ie/akn/ie/debateRecord...
#
#   division.debate.debateSection division.debate.formats.pdf  \
# 0                      dbsect_2                        None
# 1                      dbsect_2                        None
# 2                      dbsect_2                        None
# ...
