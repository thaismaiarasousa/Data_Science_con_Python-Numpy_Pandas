# %%
import pandas as pd
import numpy as np

# %%
df_ventas=pd.read_excel(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\CASO PRÁCTICO 1\Ventas.xlsx')

# %%
df_ventas
# Out:
#            ID Pedido Fecha compra         Fecha envío      Modo envío  \
# 0     CA-2016-152156   2020-11-08 2020-11-11 05:00:00    Second Class
# 1     CA-2016-152156   2020-11-08 2020-11-11 00:00:00    Second Class
# 2     CA-2016-138688   2020-06-12 2020-06-16 00:00:00    Second Class
# 3     US-2015-108966   2019-10-11                 NaT  Standard Class
# 4     US-2015-108966   2019-10-11 2019-10-18 00:00:00  Standard Class
# ...              ...          ...                 ...             ...
# 9989  CA-2014-110422   2018-01-21 2018-01-23 00:00:00    Second Class
# 9990  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9991  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9992  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9993  CA-2017-119914   2021-05-04 2021-05-09 00:00:00    Second Class
#
#      ID Cliente      ID Producto Precio unitario  Cantidad
# 0      CG-12520  FUR-BO-10001798          261,96         2
# ...

# %%
df_ventas["Precio unitario"]=df_ventas["Precio unitario"].apply(lambda x:x.replace(",","."))

# %%
df_ventas
# Out:
#            ID Pedido Fecha compra         Fecha envío      Modo envío  \
# 0     CA-2016-152156   2020-11-08 2020-11-11 05:00:00    Second Class
# 1     CA-2016-152156   2020-11-08 2020-11-11 00:00:00    Second Class
# 2     CA-2016-138688   2020-06-12 2020-06-16 00:00:00    Second Class
# 3     US-2015-108966   2019-10-11                 NaT  Standard Class
# 4     US-2015-108966   2019-10-11 2019-10-18 00:00:00  Standard Class
# ...              ...          ...                 ...             ...
# 9989  CA-2014-110422   2018-01-21 2018-01-23 00:00:00    Second Class
# 9990  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9991  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9992  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9993  CA-2017-119914   2021-05-04 2021-05-09 00:00:00    Second Class
#
#      ID Cliente      ID Producto Precio unitario  Cantidad
# 0      CG-12520  FUR-BO-10001798          261.96         2
# ...

# %%
df_ventas.isnull() #Verifico si hay valores NaN
# Out:
#       ID Pedido  Fecha compra  Fecha envío  Modo envío  ID Cliente  \
# 0         False         False        False       False       False
# 1         False         False        False       False       False
# 2         False         False        False       False       False
# 3         False         False         True       False       False
# 4         False         False        False       False       False
# ...         ...           ...          ...         ...         ...
# 9989      False         False        False       False       False
# 9990      False         False        False       False       False
# 9991      False         False        False       False       False
# 9992      False         False        False       False       False
# 9993      False         False        False       False       False
#
#       ID Producto  Precio unitario  Cantidad
# 0           False            False     False
# 1           False            False     False
# ...

# %%
df_ventas.count()
# Out:
# ID Pedido          9994
# Fecha compra       9991
# Fecha envío        9988
# Modo envío         9994
# ID Cliente         9994
# ID Producto        9994
# Precio unitario    9994
# Cantidad           9994
# dtype: int64

# %%
df_ventas.drop_duplicates(inplace=True) #Elimino valores duplicados

# %%
df_ventas.dropna(inplace=True) #Elimino valores NaN

# %%
df_ventas.count() #Visualizo valores nonNa
# Out:
# ID Pedido          9984
# Fecha compra       9984
# Fecha envío        9984
# Modo envío         9984
# ID Cliente         9984
# ID Producto        9984
# Precio unitario    9984
# Cantidad           9984
# dtype: int64

# %%
df_ventas_eliminados=9994-9984 #Calculo la cantidad de valores eliminados

# %%
df_ventas_eliminados
# Out:
# 10

# %%
#Calculo la mediana del total de ventas:

# %%
df_ventas["Precio unitario"]=pd.to_numeric(df_ventas["Precio unitario"])
df_ventas["Cantidad"]=pd.to_numeric(df_ventas["Cantidad"])

# %%
df_ventas["Precio_final"]=df_ventas.apply(lambda x:x["Precio unitario"]*x["Cantidad"],axis=1)

# %%
df_ventas
# Out:
#            ID Pedido Fecha compra         Fecha envío      Modo envío  \
# 0     CA-2016-152156   2020-11-08 2020-11-11 05:00:00    Second Class
# 1     CA-2016-152156   2020-11-08 2020-11-11 00:00:00    Second Class
# 2     CA-2016-138688   2020-06-12 2020-06-16 00:00:00    Second Class
# 4     US-2015-108966   2019-10-11 2019-10-18 00:00:00  Standard Class
# 5     CA-2014-115812   2018-06-09 2018-06-14 00:00:00  Standard Class
# ...              ...          ...                 ...             ...
# 9989  CA-2014-110422   2018-01-21 2018-01-23 00:00:00    Second Class
# 9990  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9991  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9992  CA-2017-121258   2021-02-26 2021-03-03 00:00:00  Standard Class
# 9993  CA-2017-119914   2021-05-04 2021-05-09 00:00:00    Second Class
#
#      ID Cliente      ID Producto  Precio unitario  Cantidad  Precio_final
# ...

# %%
df_ventas["Precio_final"].median()
# Out:
# 183.68

# %%
#Calculo cuantos de los productos no superan los 75% de los pedidos de los clientes:

# %% [markdown]
# # Clientes

# %%
df_clientes=pd.read_excel(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\CASO PRÁCTICO 1\Clientes.xlsx')

# %%
df_clientes
# Out:
#     ID Cliente     Nombre cliente     Segmento           País  \
# 0     CG-12520        Claire Gute     Consumer  United States
# 1     DV-13045    Darrin Van Huff    Corporate  United States
# 2     SO-20335     Sean O'Donnell     Consumer  United States
# 3     BH-11710    Brosina Hoffman     Consumer  United States
# 4     AA-10480       Andrew Allen     Consumer  United States
# ..         ...                ...          ...            ...
# 788   CJ-11875       Carl Jackson    Corporate        Romania
# 789   RS-19870         Roy Skaria  Home Office        Romania
# 790   SC-20845         Sung Chung     Consumer        Romania
# 791   RE-19405    Ricardo Emerson     Consumer        Romania
# 792   SM-20905  Susan MacKendrick     Consumer        Romania
#
#               Ciudad          Estado  Código Postal Región
# 0          Henderson        Kentucky        42420.0  South
# 1        Los Angeles      California        90036.0   West
# ...

# %%
df_clientes.count()
# Out:
# ID Cliente        793
# Nombre cliente    793
# Segmento          793
# País              793
# Ciudad            338
# Estado            338
# Código Postal     338
# Región            338
# dtype: int64

# %%
df_clientes.isnull()
# Out:
#      ID Cliente  Nombre cliente  Segmento   País  Ciudad  Estado  \
# 0         False           False     False  False   False   False
# 1         False           False     False  False   False   False
# 2         False           False     False  False   False   False
# 3         False           False     False  False   False   False
# 4         False           False     False  False   False   False
# ..          ...             ...       ...    ...     ...     ...
# 788       False           False     False  False    True    True
# 789       False           False     False  False    True    True
# 790       False           False     False  False    True    True
# 791       False           False     False  False    True    True
# 792       False           False     False  False    True    True
#
#      Código Postal  Región
# 0            False   False
# 1            False   False
# 2            False   False
# 3            False   False
# 4            False   False
# ...

# %%
df_clientes.dropna(inplace=True)

# %%
df_clientes.count()
# Out:
# ID Cliente        338
# Nombre cliente    338
# Segmento          338
# País              338
# Ciudad            338
# Estado            338
# Código Postal     338
# Región            338
# dtype: int64

# %% [markdown]
# # Productos

# %%
df_productos=pd.read_excel(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\CASO PRÁCTICO 1\Productos.xlsx')

# %%
df_productos
# Out:
#           ID Producto        Categoría Sub-categoría  \
# 0     FUR-BO-10001798        Furniture     Bookcases
# 1     FUR-CH-10000454        Furniture        Chairs
# 2     OFF-LA-10000240  Office Supplies        Labels
# 3     FUR-TA-10000577        Furniture        Tables
# 4     OFF-ST-10000760  Office Supplies       Storage
# ...               ...              ...           ...
# 1859  TEC-MA-10003589       Technology      Machines
# 1860  OFF-AP-10003099  Office Supplies    Appliances
# 1861  TEC-PH-10002645       Technology        Phones
# 1862  OFF-ST-10001627  Office Supplies       Storage
# 1863  OFF-BI-10003656  Office Supplies       Binders
#
#                                         Nombre Producto  Coste Producción
# 0                     Bush Somerset Collection Bookcase        230.098156
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...        563.102730
# 2     Self-Adhesive Address Labels for Typewriters b...         11.746474
# ...

# %%
df_productos.count()
# Out:
# ID Producto         1864
# Categoría           1864
# Sub-categoría       1864
# Nombre Producto     1863
# Coste Producción    1862
# dtype: int64

# %%
df_productos.isnull()
# Out:
#       ID Producto  Categoría  Sub-categoría  Nombre Producto  Coste Producción
# 0           False      False          False            False             False
# 1           False      False          False            False             False
# 2           False      False          False            False             False
# 3           False      False          False            False             False
# 4           False      False          False            False             False
# ...           ...        ...            ...              ...               ...
# 1859        False      False          False            False             False
# 1860        False      False          False            False             False
# 1861        False      False          False            False             False
# 1862        False      False          False            False             False
# 1863        False      False          False            False             False
#
# [1864 rows x 5 columns]

# %%
df_productos.dropna(inplace=True)

# %%
df_productos.count()
# Out:
# ID Producto         1862
# Categoría           1862
# Sub-categoría       1862
# Nombre Producto     1862
# Coste Producción    1862
# dtype: int64

# %% [markdown]
# # Poblacion

# %%
df_pob=pd.read_excel(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\CASO PRÁCTICO 1\Exportado_Población_PIB.xlsx')

# %%
df_pob
# Out:
#        #              Country  GDP (nominal, 2017)     GDP (abbrev.)  \
# 0      1        United States  $19,485,394,000,000  $19.485 trillion
# 1      2                China  $12,237,700,479,375  $12.238 trillion
# 2      3                Japan   $4,872,415,104,315   $4.872 trillion
# 3      4              Germany   $3,693,204,332,230   $3.693 trillion
# 4      5                India   $2,650,725,335,364   $2.651 trillion
# ..   ...                  ...                  ...               ...
# 184  185  Sao Tome & Principe         $392,570,293      $393 million
# 185  186                Palau         $289,823,500      $290 million
# 186  187     Marshall Islands         $204,173,430      $204 million
# 187  188             Kiribati         $185,572,502      $186 million
# 188  189               Tuvalu          $39,731,317       $40 million
#
#     GDP growth Population -2017 GDP per capita Share of World GDP
# 0        2.27%      325,084,756        $59,939             24.08%
# ...

# %%
df_pob.count()
# Out:
# #                      189
# Country                189
# GDP (nominal, 2017)    189
# GDP (abbrev.)          189
# GDP growth             189
# Population -2017       189
# GDP per capita         189
# Share of World GDP     189
# dtype: int64

# %% [markdown]
# # PIB

# %%
df_pib=pd.read_excel(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\CASO PRÁCTICO 1\Exportado_Población_PIB.xlsx')

# %%
df_pib
# Out:
#        #              Country  GDP (nominal, 2017)     GDP (abbrev.)  \
# 0      1        United States  $19,485,394,000,000  $19.485 trillion
# 1      2                China  $12,237,700,479,375  $12.238 trillion
# 2      3                Japan   $4,872,415,104,315   $4.872 trillion
# 3      4              Germany   $3,693,204,332,230   $3.693 trillion
# 4      5                India   $2,650,725,335,364   $2.651 trillion
# ..   ...                  ...                  ...               ...
# 184  185  Sao Tome & Principe         $392,570,293      $393 million
# 185  186                Palau         $289,823,500      $290 million
# 186  187     Marshall Islands         $204,173,430      $204 million
# 187  188             Kiribati         $185,572,502      $186 million
# 188  189               Tuvalu          $39,731,317       $40 million
#
#     GDP growth Population -2017 GDP per capita Share of World GDP
# 0        2.27%      325,084,756        $59,939             24.08%
# ...

# %%
df_pib.count()
# Out:
# #                      189
# Country                189
# GDP (nominal, 2017)    189
# GDP (abbrev.)          189
# GDP growth             189
# Population -2017       189
# GDP per capita         189
# Share of World GDP     189
# dtype: int64

# %% [markdown]
# # Renta Per Capita

# %%
df_rpc=pd.read_excel(r'C:\Users\thais\Desktop\Curso Python e Analise de Dados\Datasets+Data+Science+con+Python+-+Pandas\CASO PRÁCTICO 1\Exportado_RPC.xlsx')

# %%
df_rpc
# Out:
#                     Country Average monthly wage
# 0               Switzerland               $7,466
# 1                Luxembourg               $5,583
# 2                    Norway               $5,418
# 3                   Denmark               $5,310
# 4             United States               $4,893
# 5                 Australia               $4,700
# 6                   Ireland               $4,379
# 7               Netherlands               $4,289
# 8                    Canada               $4,134
# 9                   Belgium               $3,963
# 10                   Sweden               $3,849
# 11                  Finland               $3,781
# 12                  Austria               $3,761
# 13                  Germany               $3,478
# 14           United Kingdom               $3,461
# 15                   France               $3,374
# 16                    Italy               $2,671
# 17                   Israel               $2,405
# ...

# %%
df_rpc.shape
# Out:
# (36, 2)

# %%
df_rpc.count()
# Out:
# Country                 36
# Average monthly wage    36
# dtype: int64
